# %%
import requests, json
import matplotlib
import matplotlib.pyplot as plt
# %matplotlib inline  

from settings import API, headers

# %%
raw_data = []
with open("./docs/btc_usd.csv", mode="r", encoding="utf-8") as f:
    for line in f.readlines():
        if not "年" in line:
            continue
        tmp = line.split('","')
        raw_data.append({
            "time":tmp[0][1:],
            "close":float(tmp[1].replace(",","")),
            "high":float(tmp[3].replace(",","")),
            "low":float(tmp[4].replace(",",""))
        })

# %%
raw_data.reverse()

# %%
plt.figure()
plt.plot([k["close"] for k in raw_data])
plt.plot([k["high"] for k in raw_data])
plt.plot([k["low"] for k in raw_data])
